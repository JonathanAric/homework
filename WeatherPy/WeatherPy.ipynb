# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
api_key = "7e7c9ea7e5e101fdbe47ad62f26705e1"


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL --base URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url

# create empty lists for weather data
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record = 1

print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record}| {city_record}")
        print(f"{url}&q={city}")
        
        record = record +1
        
    except:
        print("City not found. Skipping...")
    continue

print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1| Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# City not found. Skipping...
# Processing Record 2| Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 3| Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 4| Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 5| Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 6| Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 7| Altamira
# http://api.openweathermap.org/data/2.5/weather?&q=altamira
# Processing Record 8| Bauchi
# http://api.openweathermap.org/data/2.5/weather?&q=bauchi
# Processing Record 9| Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 10| Georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 11| Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 12| Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 13| Taoudenni
# http://api.openweathermap.org/data/2.5/weather?&q=taoudenni
# Processing Record 14| Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=thinadhoo
# Processing Record 15| Mount Isa
# http://api.openweathermap.org/data/2.5/weather?&q=mount isa
# Processing Record 16| Altagracia de Orituco
# http://api.openweathermap.org/data/2.5/weather?&q=altagracia de orituco
# Processing Record 17| Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 18| Port Hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# Processing Record 19| Aksarka
# http://api.openweathermap.org/data/2.5/weather?&q=aksarka
# Processing Record 20| Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 21| Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 22| Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?&q=puerto escondido
# Processing Record 23| Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 24| Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 25| Hovd
# http://api.openweathermap.org/data/2.5/weather?&q=hovd
# Processing Record 26| Yagodnoye
# http://api.openweathermap.org/data/2.5/weather?&q=yagodnoye
# Processing Record 27| Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?&q=ust-tsilma
# Processing Record 28| Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 29| Altay
# http://api.openweathermap.org/data/2.5/weather?&q=altay
# Processing Record 30| Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# City not found. Skipping...
# Processing Record 31| Waipawa
# http://api.openweathermap.org/data/2.5/weather?&q=waipawa
# Processing Record 32| Cookeville
# http://api.openweathermap.org/data/2.5/weather?&q=cookeville
# Processing Record 33| Zyryanka
# http://api.openweathermap.org/data/2.5/weather?&q=zyryanka
# Processing Record 34| Freeport
# http://api.openweathermap.org/data/2.5/weather?&q=freeport
# Processing Record 35| Jijiga
# http://api.openweathermap.org/data/2.5/weather?&q=jijiga
# Processing Record 36| Liverpool
# http://api.openweathermap.org/data/2.5/weather?&q=liverpool
# Processing Record 37| Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 38| Gimli
# http://api.openweathermap.org/data/2.5/weather?&q=gimli
# Processing Record 39| Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 40| Buraydah
# http://api.openweathermap.org/data/2.5/weather?&q=buraydah
# Processing Record 41| Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 42| New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 43| Teya
# http://api.openweathermap.org/data/2.5/weather?&q=teya
# Processing Record 44| Chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 45| Atambua
# http://api.openweathermap.org/data/2.5/weather?&q=atambua
# Processing Record 46| Kununurra
# http://api.openweathermap.org/data/2.5/weather?&q=kununurra
# Processing Record 47| Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# City not found. Skipping...
# Processing Record 48| Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 49| Santa Maria
# http://api.openweathermap.org/data/2.5/weather?&q=santa maria
# Processing Record 50| Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 51| Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=floresta
# Processing Record 52| Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# Processing Record 53| Doha
# http://api.openweathermap.org/data/2.5/weather?&q=doha
# City not found. Skipping...
# Processing Record 54| Kurchum
# http://api.openweathermap.org/data/2.5/weather?&q=kurchum
# Processing Record 55| Mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 56| Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 57| Boulder City
# http://api.openweathermap.org/data/2.5/weather?&q=boulder city
# Processing Record 58| Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 59| Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnevilyuysk
# Processing Record 60| Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# City not found. Skipping...
# Processing Record 61| Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 62| Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 63| Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 64| Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 65| Sisimiut
# http://api.openweathermap.org/data/2.5/weather?&q=sisimiut
# Processing Record 66| Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 67| Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# Processing Record 68| Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 69| Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 70| Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 71| Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 72| Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 73| Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# City not found. Skipping...
# Processing Record 74| Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 75| Herat
# http://api.openweathermap.org/data/2.5/weather?&q=herat
# Processing Record 76| Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 77| Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 78| Bilibino
# http://api.openweathermap.org/data/2.5/weather?&q=bilibino
# Processing Record 79| Yumbe
# http://api.openweathermap.org/data/2.5/weather?&q=yumbe
# Processing Record 80| Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 81| Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 82| Margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 83| Ostersund
# http://api.openweathermap.org/data/2.5/weather?&q=ostersund
# Processing Record 84| Sistranda
# http://api.openweathermap.org/data/2.5/weather?&q=sistranda
# Processing Record 85| Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 86| Alenquer
# http://api.openweathermap.org/data/2.5/weather?&q=alenquer
# Processing Record 87| Severnoye
# http://api.openweathermap.org/data/2.5/weather?&q=severnoye
# Processing Record 88| Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 89| Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# City not found. Skipping...
# Processing Record 90| Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# City not found. Skipping...
# Processing Record 91| Carutapera
# http://api.openweathermap.org/data/2.5/weather?&q=carutapera
# Processing Record 92| Kirakira
# http://api.openweathermap.org/data/2.5/weather?&q=kirakira
# Processing Record 93| Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 94| Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 95| Christchurch
# http://api.openweathermap.org/data/2.5/weather?&q=christchurch
# Processing Record 96| Armidale
# http://api.openweathermap.org/data/2.5/weather?&q=armidale
# Processing Record 97| Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# Processing Record 98| Karlstad
# http://api.openweathermap.org/data/2.5/weather?&q=karlstad
# Processing Record 99| Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 100| Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?&q=qaqortoq
# Processing Record 101| Luanda
# http://api.openweathermap.org/data/2.5/weather?&q=luanda
# Processing Record 102| Salinopolis
# http://api.openweathermap.org/data/2.5/weather?&q=salinopolis
# Processing Record 103| Klaksvik
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 104| Makakilo City
# http://api.openweathermap.org/data/2.5/weather?&q=makakilo city
# Processing Record 105| Sobolevo
# http://api.openweathermap.org/data/2.5/weather?&q=sobolevo
# Processing Record 106| Hobyo
# http://api.openweathermap.org/data/2.5/weather?&q=hobyo
# Processing Record 107| Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?&q=port-gentil
# Processing Record 108| Magan
# http://api.openweathermap.org/data/2.5/weather?&q=magan
# Processing Record 109| Novoagansk
# http://api.openweathermap.org/data/2.5/weather?&q=novoagansk
# Processing Record 110| Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 111| La Rioja
# http://api.openweathermap.org/data/2.5/weather?&q=la rioja
# Processing Record 112| Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 113| Anshun
# http://api.openweathermap.org/data/2.5/weather?&q=anshun
# Processing Record 114| Luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 115| Witbank
# http://api.openweathermap.org/data/2.5/weather?&q=witbank
# Processing Record 116| Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 117| Salta
# http://api.openweathermap.org/data/2.5/weather?&q=salta
# Processing Record 118| Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?&q=leningradskiy
# Processing Record 119| San-Pedro
# http://api.openweathermap.org/data/2.5/weather?&q=san-pedro
# Processing Record 120| Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 121| Taganak
# http://api.openweathermap.org/data/2.5/weather?&q=taganak
# Processing Record 122| Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 123| Ngunguru
# http://api.openweathermap.org/data/2.5/weather?&q=ngunguru
# Processing Record 124| Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 125| Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?&q=port lincoln
# Processing Record 126| Marystown
# http://api.openweathermap.org/data/2.5/weather?&q=marystown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 127| Mamlyutka
# http://api.openweathermap.org/data/2.5/weather?&q=mamlyutka
# Processing Record 128| Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 129| Talnakh
# http://api.openweathermap.org/data/2.5/weather?&q=talnakh
# Processing Record 130| Kidal
# http://api.openweathermap.org/data/2.5/weather?&q=kidal
# Processing Record 131| Panzhihua
# http://api.openweathermap.org/data/2.5/weather?&q=panzhihua
# Processing Record 132| Ucluelet
# http://api.openweathermap.org/data/2.5/weather?&q=ucluelet
# Processing Record 133| Prince George
# http://api.openweathermap.org/data/2.5/weather?&q=prince george
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 134| Kirovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=kirovskiy
# Processing Record 135| Iberia
# http://api.openweathermap.org/data/2.5/weather?&q=iberia
# Processing Record 136| San Lazaro
# http://api.openweathermap.org/data/2.5/weather?&q=san lazaro
# Processing Record 137| Great Falls
# http://api.openweathermap.org/data/2.5/weather?&q=great falls
# Processing Record 138| Namatanai
# http://api.openweathermap.org/data/2.5/weather?&q=namatanai
# Processing Record 139| Puri
# http://api.openweathermap.org/data/2.5/weather?&q=puri
# Processing Record 140| Kavaratti
# http://api.openweathermap.org/data/2.5/weather?&q=kavaratti
# Processing Record 141| Bhatkal
# http://api.openweathermap.org/data/2.5/weather?&q=bhatkal
# Processing Record 142| Husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# Processing Record 143| Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 144| Brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# City not found. Skipping...
# Processing Record 145| Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 146| Zempoala
# http://api.openweathermap.org/data/2.5/weather?&q=zempoala
# Processing Record 147| Furano
# http://api.openweathermap.org/data/2.5/weather?&q=furano
# Processing Record 148| Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# City not found. Skipping...
# Processing Record 149| Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# Processing Record 150| Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?&q=nhulunbuy
# Processing Record 151| Iquitos
# http://api.openweathermap.org/data/2.5/weather?&q=iquitos
# Processing Record 152| Yelyzavethradka
# http://api.openweathermap.org/data/2.5/weather?&q=yelyzavethradka
# Processing Record 153| Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# Processing Record 154| Chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 155| Gambela
# http://api.openweathermap.org/data/2.5/weather?&q=gambela
# Processing Record 156| Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 157| Te Anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 158| Inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# Processing Record 159| Keshorai Patan
# http://api.openweathermap.org/data/2.5/weather?&q=keshorai patan
# Processing Record 160| Boa Vista
# http://api.openweathermap.org/data/2.5/weather?&q=boa vista
# Processing Record 161| Dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 162| Nizhneangarsk
# http://api.openweathermap.org/data/2.5/weather?&q=nizhneangarsk
# City not found. Skipping...
# Processing Record 163| Dalen
# http://api.openweathermap.org/data/2.5/weather?&q=dalen
# Processing Record 164| Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 165| Kaohsiung
# http://api.openweathermap.org/data/2.5/weather?&q=kaohsiung
# Processing Record 166| Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?&q=sao jose da coroa grande
# City not found. Skipping...
# Processing Record 167| Gizo
# http://api.openweathermap.org/data/2.5/weather?&q=gizo
# Processing Record 168| Chinhoyi
# http://api.openweathermap.org/data/2.5/weather?&q=chinhoyi
# Processing Record 169| General Pico
# http://api.openweathermap.org/data/2.5/weather?&q=general pico
# Processing Record 170| Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 171| Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 172| Bontang
# http://api.openweathermap.org/data/2.5/weather?&q=bontang
# Processing Record 173| Micheldorf
# http://api.openweathermap.org/data/2.5/weather?&q=micheldorf
# Processing Record 174| Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 175| Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 176| Kuala Terengganu
# http://api.openweathermap.org/data/2.5/weather?&q=kuala terengganu
# Processing Record 177| Punta Umbria
# http://api.openweathermap.org/data/2.5/weather?&q=punta umbria
# Processing Record 178| San Juan
# http://api.openweathermap.org/data/2.5/weather?&q=san juan
# Processing Record 179| Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?&q=lavrentiya
# Processing Record 180| Shubarkuduk
# http://api.openweathermap.org/data/2.5/weather?&q=shubarkuduk
# Processing Record 181| Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 182| Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 183| Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 184| La Ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 185| Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 186| Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?&q=saint-louis
# City not found. Skipping...
# Processing Record 187| Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 188| Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 189| Kiruna
# http://api.openweathermap.org/data/2.5/weather?&q=kiruna
# Processing Record 190| Manono
# http://api.openweathermap.org/data/2.5/weather?&q=manono
# Processing Record 191| Inongo
# http://api.openweathermap.org/data/2.5/weather?&q=inongo
# City not found. Skipping...
# Processing Record 192| Espanola
# http://api.openweathermap.org/data/2.5/weather?&q=espanola
# Processing Record 193| Camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# Processing Record 194| Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?&q=luang prabang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 195| Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 196| Basco
# http://api.openweathermap.org/data/2.5/weather?&q=basco
# Processing Record 197| Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 198| Lyngseidet
# http://api.openweathermap.org/data/2.5/weather?&q=lyngseidet
# Processing Record 199| Broken Hill
# http://api.openweathermap.org/data/2.5/weather?&q=broken hill
# Processing Record 200| Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?&q=lakes entrance
# Processing Record 201| Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# City not found. Skipping...
# Processing Record 202| Takoradi
# http://api.openweathermap.org/data/2.5/weather?&q=takoradi
# Processing Record 203| LOS ALGARROBOS
# http://api.openweathermap.org/data/2.5/weather?&q=los algarrobos
# Processing Record 204| Canayan
# http://api.openweathermap.org/data/2.5/weather?&q=canayan
# Processing Record 205| Riyadh
# http://api.openweathermap.org/data/2.5/weather?&q=riyadh
# Processing Record 206| Dawlatabad
# http://api.openweathermap.org/data/2.5/weather?&q=dawlatabad
# Processing Record 207| Agara
# http://api.openweathermap.org/data/2.5/weather?&q=agara
# Processing Record 208| New Ulm
# http://api.openweathermap.org/data/2.5/weather?&q=new ulm
# Processing Record 209| Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?&q=fort nelson
# Processing Record 210| Zhuhai
# http://api.openweathermap.org/data/2.5/weather?&q=zhuhai
# Processing Record 211| Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 212| Srandakan
# http://api.openweathermap.org/data/2.5/weather?&q=srandakan
# Processing Record 213| Beinamar
# http://api.openweathermap.org/data/2.5/weather?&q=beinamar
# Processing Record 214| Nikko
# http://api.openweathermap.org/data/2.5/weather?&q=nikko
# Processing Record 215| Maiduguri
# http://api.openweathermap.org/data/2.5/weather?&q=maiduguri
# Processing Record 216| Ternate
# http://api.openweathermap.org/data/2.5/weather?&q=ternate
# Processing Record 217| Mirador
# http://api.openweathermap.org/data/2.5/weather?&q=mirador
# Processing Record 218| Shingu
# http://api.openweathermap.org/data/2.5/weather?&q=shingu
# Processing Record 219| Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 220| Haines Junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 221| Muros
# http://api.openweathermap.org/data/2.5/weather?&q=muros
# Processing Record 222| Jiwani
# http://api.openweathermap.org/data/2.5/weather?&q=jiwani
# Processing Record 223| Gigmoto
# http://api.openweathermap.org/data/2.5/weather?&q=gigmoto
# Processing Record 224| Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 225| Padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 226| Iguape
# http://api.openweathermap.org/data/2.5/weather?&q=iguape
# City not found. Skipping...
# Processing Record 227| Guarapari
# http://api.openweathermap.org/data/2.5/weather?&q=guarapari
# Processing Record 228| Mangan
# http://api.openweathermap.org/data/2.5/weather?&q=mangan
# Processing Record 229| Coahuayana
# http://api.openweathermap.org/data/2.5/weather?&q=coahuayana
# Processing Record 230| Chipinge
# http://api.openweathermap.org/data/2.5/weather?&q=chipinge
# Processing Record 231| Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?&q=jacareacanga
# Processing Record 232| Itarema
# http://api.openweathermap.org/data/2.5/weather?&q=itarema
# Processing Record 233| East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# City not found. Skipping...
# Processing Record 234| Nuuk
# http://api.openweathermap.org/data/2.5/weather?&q=nuuk
# Processing Record 235| Lieksa
# http://api.openweathermap.org/data/2.5/weather?&q=lieksa
# Processing Record 236| Grenaa
# http://api.openweathermap.org/data/2.5/weather?&q=grenaa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 237| Vaitape
# http://api.openweathermap.org/data/2.5/weather?&q=vaitape
# Processing Record 238| Buchanan
# http://api.openweathermap.org/data/2.5/weather?&q=buchanan
# Processing Record 239| Kuching
# http://api.openweathermap.org/data/2.5/weather?&q=kuching
# Processing Record 240| Ancud
# http://api.openweathermap.org/data/2.5/weather?&q=ancud
# Processing Record 241| Nordfjordeid
# http://api.openweathermap.org/data/2.5/weather?&q=nordfjordeid
# Processing Record 242| Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 243| Boralday
# http://api.openweathermap.org/data/2.5/weather?&q=boralday
# Processing Record 244| Codrington
# http://api.openweathermap.org/data/2.5/weather?&q=codrington
# Processing Record 245| Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 246| Muzaffarpur
# http://api.openweathermap.org/data/2.5/weather?&q=muzaffarpur
# Processing Record 247| Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 248| Manggar
# http://api.openweathermap.org/data/2.5/weather?&q=manggar
# Processing Record 249| Sola
# http://api.openweathermap.org/data/2.5/weather?&q=sola
# Processing Record 250| Bonthe
# http://api.openweathermap.org/data/2.5/weather?&q=bonthe
# Processing Record 251| Goma
# http://api.openweathermap.org/data/2.5/weather?&q=goma
# Processing Record 252| Kaeo
# http://api.openweathermap.org/data/2.5/weather?&q=kaeo
# Processing Record 253| Muisne
# http://api.openweathermap.org/data/2.5/weather?&q=muisne
# Processing Record 254| Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 255| Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?&q=yerbogachen
# Processing Record 256| Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 257| Fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 258| Daman
# http://api.openweathermap.org/data/2.5/weather?&q=daman
# Processing Record 259| Ishigaki
# http://api.openweathermap.org/data/2.5/weather?&q=ishigaki
# Processing Record 260| Natchitoches
# http://api.openweathermap.org/data/2.5/weather?&q=natchitoches
# Processing Record 261| Muzhi
# http://api.openweathermap.org/data/2.5/weather?&q=muzhi
# Processing Record 262| Hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 263| Lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 264| Ghanzi
# http://api.openweathermap.org/data/2.5/weather?&q=ghanzi
# Processing Record 265| Necochea
# http://api.openweathermap.org/data/2.5/weather?&q=necochea
# Processing Record 266| Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# Processing Record 267| Russell
# http://api.openweathermap.org/data/2.5/weather?&q=russell
# Processing Record 268| Edd
# http://api.openweathermap.org/data/2.5/weather?&q=edd
# Processing Record 269| Richmond
# http://api.openweathermap.org/data/2.5/weather?&q=richmond
# Processing Record 270| Tabas
# http://api.openweathermap.org/data/2.5/weather?&q=tabas
# Processing Record 271| Romny
# http://api.openweathermap.org/data/2.5/weather?&q=romny
# Processing Record 272| Awjilah
# http://api.openweathermap.org/data/2.5/weather?&q=awjilah
# Processing Record 273| Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 274| Norman Wells
# http://api.openweathermap.org/data/2.5/weather?&q=norman wells
# Processing Record 275| Wattegama
# http://api.openweathermap.org/data/2.5/weather?&q=wattegama
# Processing Record 276| Mbanza-Ngungu
# http://api.openweathermap.org/data/2.5/weather?&q=mbanza-ngungu
# Processing Record 277| Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?&q=santa rosa
# Processing Record 278| San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 279| Havoysund
# http://api.openweathermap.org/data/2.5/weather?&q=havoysund
# City not found. Skipping...
# Processing Record 280| Ha Tinh
# http://api.openweathermap.org/data/2.5/weather?&q=ha tinh
# Processing Record 281| Plouzane
# http://api.openweathermap.org/data/2.5/weather?&q=plouzane
# Processing Record 282| Mercedes
# http://api.openweathermap.org/data/2.5/weather?&q=mercedes
# Processing Record 283| Kalmunai
# http://api.openweathermap.org/data/2.5/weather?&q=kalmunai
# Processing Record 284| Carandai
# http://api.openweathermap.org/data/2.5/weather?&q=carandai
# Processing Record 285| Faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 286| Port Augusta
# http://api.openweathermap.org/data/2.5/weather?&q=port augusta
# Processing Record 287| Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?&q=qasigiannguit
# Processing Record 288| Yangjiang
# http://api.openweathermap.org/data/2.5/weather?&q=yangjiang
# Processing Record 289| Parbatipur
# http://api.openweathermap.org/data/2.5/weather?&q=parbatipur
# Processing Record 290| Maragogi
# http://api.openweathermap.org/data/2.5/weather?&q=maragogi
# Processing Record 291| Mogadishu
# http://api.openweathermap.org/data/2.5/weather?&q=mogadishu
# Processing Record 292| Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# City not found. Skipping...
# Processing Record 293| Mogok
# http://api.openweathermap.org/data/2.5/weather?&q=mogok
# Processing Record 294| Stabat
# http://api.openweathermap.org/data/2.5/weather?&q=stabat
# Processing Record 295| Nishihara
# http://api.openweathermap.org/data/2.5/weather?&q=nishihara
# Processing Record 296| Progreso
# http://api.openweathermap.org/data/2.5/weather?&q=progreso
# Processing Record 297| Mount Pleasant
# http://api.openweathermap.org/data/2.5/weather?&q=mount pleasant
# City not found. Skipping...
# Processing Record 298| Rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 299| Tokur
# http://api.openweathermap.org/data/2.5/weather?&q=tokur
# Processing Record 300| Corner Brook
# http://api.openweathermap.org/data/2.5/weather?&q=corner brook
# Processing Record 301| Gat
# http://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 302| Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# Processing Record 303| Tartagal
# http://api.openweathermap.org/data/2.5/weather?&q=tartagal
# Processing Record 304| Jeremie
# http://api.openweathermap.org/data/2.5/weather?&q=jeremie
# Processing Record 305| Teknaf
# http://api.openweathermap.org/data/2.5/weather?&q=teknaf
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 306| Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 307| Egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 308| Huinan
# http://api.openweathermap.org/data/2.5/weather?&q=huinan
# Processing Record 309| Toora-Khem
# http://api.openweathermap.org/data/2.5/weather?&q=toora-khem
# Processing Record 310| Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 311| Boende
# http://api.openweathermap.org/data/2.5/weather?&q=boende
# City not found. Skipping...
# Processing Record 312| San Cristobal
# http://api.openweathermap.org/data/2.5/weather?&q=san cristobal
# Processing Record 313| Iquique
# http://api.openweathermap.org/data/2.5/weather?&q=iquique
# Processing Record 314| Dakar
# http://api.openweathermap.org/data/2.5/weather?&q=dakar
# City not found. Skipping...
# Processing Record 315| Yaring
# http://api.openweathermap.org/data/2.5/weather?&q=yaring
# Processing Record 316| Sarh
# http://api.openweathermap.org/data/2.5/weather?&q=sarh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 317| Paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# City not found. Skipping...
# Processing Record 318| Shishou
# http://api.openweathermap.org/data/2.5/weather?&q=shishou
# Processing Record 319| Clearlake
# http://api.openweathermap.org/data/2.5/weather?&q=clearlake
# Processing Record 320| Alugan
# http://api.openweathermap.org/data/2.5/weather?&q=alugan
# Processing Record 321| College
# http://api.openweathermap.org/data/2.5/weather?&q=college
# City not found. Skipping...
# Processing Record 322| Miles City
# http://api.openweathermap.org/data/2.5/weather?&q=miles city
# Processing Record 323| Zhigansk
# http://api.openweathermap.org/data/2.5/weather?&q=zhigansk
# City not found. Skipping...
# Processing Record 324| Tarauaca
# http://api.openweathermap.org/data/2.5/weather?&q=tarauaca
# Processing Record 325| Zalantun
# http://api.openweathermap.org/data/2.5/weather?&q=zalantun
# Processing Record 326| Avera
# http://api.openweathermap.org/data/2.5/weather?&q=avera
# Processing Record 327| Uthal
# http://api.openweathermap.org/data/2.5/weather?&q=uthal
# Processing Record 328| Kushima
# http://api.openweathermap.org/data/2.5/weather?&q=kushima
# Processing Record 329| Kathu
# http://api.openweathermap.org/data/2.5/weather?&q=kathu
# Processing Record 330| Saint Augustine
# http://api.openweathermap.org/data/2.5/weather?&q=saint augustine
# Processing Record 331| Qadian
# http://api.openweathermap.org/data/2.5/weather?&q=qadian
# Processing Record 332| Kalabo
# http://api.openweathermap.org/data/2.5/weather?&q=kalabo
# Processing Record 333| Beloha
# http://api.openweathermap.org/data/2.5/weather?&q=beloha
# Processing Record 334| Ndungu
# http://api.openweathermap.org/data/2.5/weather?&q=ndungu
# Processing Record 335| Nantucket
# http://api.openweathermap.org/data/2.5/weather?&q=nantucket
# Processing Record 336| Xining
# http://api.openweathermap.org/data/2.5/weather?&q=xining
# Processing Record 337| Rumonge
# http://api.openweathermap.org/data/2.5/weather?&q=rumonge
# Processing Record 338| Rome
# http://api.openweathermap.org/data/2.5/weather?&q=roma
# Processing Record 339| Bata
# http://api.openweathermap.org/data/2.5/weather?&q=bata
# Processing Record 340| Peleduy
# http://api.openweathermap.org/data/2.5/weather?&q=peleduy
# Processing Record 341| Bijar
# http://api.openweathermap.org/data/2.5/weather?&q=bijar
# Processing Record 342| Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 343| Tulun
# http://api.openweathermap.org/data/2.5/weather?&q=tulun
# Processing Record 344| Barsovo
# http://api.openweathermap.org/data/2.5/weather?&q=barsovo
# Processing Record 345| Benghazi
# http://api.openweathermap.org/data/2.5/weather?&q=benghazi
# Processing Record 346| Chandbali
# http://api.openweathermap.org/data/2.5/weather?&q=chandbali
# Processing Record 347| Haimen
# http://api.openweathermap.org/data/2.5/weather?&q=haimen
# Processing Record 348| Hirara
# http://api.openweathermap.org/data/2.5/weather?&q=hirara
# Processing Record 349| San Joaquin
# http://api.openweathermap.org/data/2.5/weather?&q=san joaquin
# Processing Record 350| Alyangula
# http://api.openweathermap.org/data/2.5/weather?&q=alyangula
# Processing Record 351| Yarada
# http://api.openweathermap.org/data/2.5/weather?&q=yarada
# Processing Record 352| Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# Processing Record 353| Lac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?&q=lac du bonnet
# Processing Record 354| Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 355| Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 356| Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 357| Marzuq
# http://api.openweathermap.org/data/2.5/weather?&q=marzuq
# Processing Record 358| Treinta y Tres
# http://api.openweathermap.org/data/2.5/weather?&q=treinta y tres
# Processing Record 359| West Wendover
# http://api.openweathermap.org/data/2.5/weather?&q=west wendover
# Processing Record 360| Namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 361| Dzaoudzi
# http://api.openweathermap.org/data/2.5/weather?&q=dzaoudzi
# Processing Record 362| Vanimo
# http://api.openweathermap.org/data/2.5/weather?&q=vanimo
# Processing Record 363| Wagar
# http://api.openweathermap.org/data/2.5/weather?&q=wagar
# Processing Record 364| Pekan
# http://api.openweathermap.org/data/2.5/weather?&q=pekan
# Processing Record 365| Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 366| Fort Morgan
# http://api.openweathermap.org/data/2.5/weather?&q=fort morgan
# Processing Record 367| Ongandjera
# http://api.openweathermap.org/data/2.5/weather?&q=ongandjera
# Processing Record 368| Nizhniy Tsasuchey
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy tsasuchey
# Processing Record 369| Honningsvag
# http://api.openweathermap.org/data/2.5/weather?&q=honningsvag
# Processing Record 370| Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?&q=coolum beach
# Processing Record 371| Chinacota
# http://api.openweathermap.org/data/2.5/weather?&q=chinacota
# Processing Record 372| Santo Antonio do Ica
# http://api.openweathermap.org/data/2.5/weather?&q=santo antonio do ica
# Processing Record 373| Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?&q=quatre cocos
# Processing Record 374| Dembi Dolo
# http://api.openweathermap.org/data/2.5/weather?&q=dembi dolo
# Processing Record 375| Xingyi
# http://api.openweathermap.org/data/2.5/weather?&q=xingyi
# Processing Record 376| Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?&q=shenjiamen
# Processing Record 377| Heide
# http://api.openweathermap.org/data/2.5/weather?&q=heide
# City not found. Skipping...
# Processing Record 378| Oistins
# http://api.openweathermap.org/data/2.5/weather?&q=oistins
# Processing Record 379| Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?&q=bandarbeyla
# Processing Record 380| Vardo
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# Processing Record 381| Todos Santos
# http://api.openweathermap.org/data/2.5/weather?&q=todos santos
# Processing Record 382| Ozernovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=ozernovskiy
# Processing Record 383| Tilichiki
# http://api.openweathermap.org/data/2.5/weather?&q=tilichiki
# Processing Record 384| Orcopampa
# http://api.openweathermap.org/data/2.5/weather?&q=orcopampa
# Processing Record 385| Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?&q=kysyl-syr
# Processing Record 386| Buncrana
# http://api.openweathermap.org/data/2.5/weather?&q=buncrana
# Processing Record 387| Karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# City not found. Skipping...
# Processing Record 388| Nyrob
# http://api.openweathermap.org/data/2.5/weather?&q=nyrob
# Processing Record 389| Saint-Paul
# http://api.openweathermap.org/data/2.5/weather?&q=saint-paul
# City not found. Skipping...
# Processing Record 390| Hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 391| Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 392| Pravokubanskiy
# http://api.openweathermap.org/data/2.5/weather?&q=pravokubanskiy
# Processing Record 393| Kodinsk
# http://api.openweathermap.org/data/2.5/weather?&q=kodinsk
# Processing Record 394| Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 395| Adrar
# http://api.openweathermap.org/data/2.5/weather?&q=adrar
# Processing Record 396| Mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 397| Samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 398| Raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 399| Macapa
# http://api.openweathermap.org/data/2.5/weather?&q=macapa
# Processing Record 400| Rizhao
# http://api.openweathermap.org/data/2.5/weather?&q=rizhao
# Processing Record 401| Colares
# http://api.openweathermap.org/data/2.5/weather?&q=colares
# Processing Record 402| Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?&q=komsomolskiy
# Processing Record 403| Kaseda
# http://api.openweathermap.org/data/2.5/weather?&q=kaseda
# Processing Record 404| Abong Mbang
# http://api.openweathermap.org/data/2.5/weather?&q=abong mbang
# Processing Record 405| Zabaykalsk
# http://api.openweathermap.org/data/2.5/weather?&q=zabaykalsk
# City not found. Skipping...
# Processing Record 406| Meadville
# http://api.openweathermap.org/data/2.5/weather?&q=meadville
# Processing Record 407| Baghdad
# http://api.openweathermap.org/data/2.5/weather?&q=baghdad
# Processing Record 408| Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 409| Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 410| Ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# Processing Record 411| Malindi
# http://api.openweathermap.org/data/2.5/weather?&q=malindi
# Processing Record 412| Trelew
# http://api.openweathermap.org/data/2.5/weather?&q=trelew
# Processing Record 413| Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?&q=baruun-urt
# Processing Record 414| Bafq
# http://api.openweathermap.org/data/2.5/weather?&q=bafq
# Processing Record 415| Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?&q=saint-francois
# Processing Record 416| Waingapu
# http://api.openweathermap.org/data/2.5/weather?&q=waingapu
# Processing Record 417| Montelibano
# http://api.openweathermap.org/data/2.5/weather?&q=montelibano
# City not found. Skipping...
# Processing Record 418| Rio Grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 419| Sungurlu
# http://api.openweathermap.org/data/2.5/weather?&q=sungurlu
# Processing Record 420| Dauphin
# http://api.openweathermap.org/data/2.5/weather?&q=dauphin
# City not found. Skipping...
# Processing Record 421| Ambon
# http://api.openweathermap.org/data/2.5/weather?&q=ambon
# Processing Record 422| Pedra Branca
# http://api.openweathermap.org/data/2.5/weather?&q=pedra branca
# Processing Record 423| Bongandanga
# http://api.openweathermap.org/data/2.5/weather?&q=bongandanga
# Processing Record 424| Baykit
# http://api.openweathermap.org/data/2.5/weather?&q=baykit
# Processing Record 425| Kotelnich
# http://api.openweathermap.org/data/2.5/weather?&q=kotelnich
# Processing Record 426| Suntar
# http://api.openweathermap.org/data/2.5/weather?&q=suntar
# Processing Record 427| Panorama
# http://api.openweathermap.org/data/2.5/weather?&q=panorama
# Processing Record 428| Zhireken
# http://api.openweathermap.org/data/2.5/weather?&q=zhireken
# Processing Record 429| Shwebo
# http://api.openweathermap.org/data/2.5/weather?&q=shwebo
# Processing Record 430| Ottumwa
# http://api.openweathermap.org/data/2.5/weather?&q=ottumwa
# Processing Record 431| Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 432| Calvinia
# http://api.openweathermap.org/data/2.5/weather?&q=calvinia
# Processing Record 433| Preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?&q=preobrazheniye
# Processing Record 434| Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# Processing Record 435| Tonantins
# http://api.openweathermap.org/data/2.5/weather?&q=tonantins
# Processing Record 436| Kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 437| Prado
# http://api.openweathermap.org/data/2.5/weather?&q=prado
# Processing Record 438| Dalvik
# http://api.openweathermap.org/data/2.5/weather?&q=dalvik
# City not found. Skipping...
# Processing Record 439| Odienne
# http://api.openweathermap.org/data/2.5/weather?&q=odienne
# Processing Record 440| Juneau
# http://api.openweathermap.org/data/2.5/weather?&q=juneau
# City not found. Skipping...
# Processing Record 441| Bogatyye Saby
# http://api.openweathermap.org/data/2.5/weather?&q=bogatyye saby
# Processing Record 442| Verkhnyaya Toyma
# http://api.openweathermap.org/data/2.5/weather?&q=verkhnyaya toyma
# Processing Record 443| Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?&q=comodoro rivadavia
# City not found. Skipping...
# Processing Record 444| Sinegorye
# http://api.openweathermap.org/data/2.5/weather?&q=sinegorye
# Processing Record 445| Manaure
# http://api.openweathermap.org/data/2.5/weather?&q=manaure
# Processing Record 446| Palmer
# http://api.openweathermap.org/data/2.5/weather?&q=palmer
# Processing Record 447| Pokhara
# http://api.openweathermap.org/data/2.5/weather?&q=pokhara
# Processing Record 448| Bowen
# http://api.openweathermap.org/data/2.5/weather?&q=bowen
# Processing Record 449| Garissa
# http://api.openweathermap.org/data/2.5/weather?&q=garissa
# Processing Record 450| Jega
# http://api.openweathermap.org/data/2.5/weather?&q=jega
# Processing Record 451| Flin Flon
# http://api.openweathermap.org/data/2.5/weather?&q=flin flon
# Processing Record 452| Luino
# http://api.openweathermap.org/data/2.5/weather?&q=luino
# Processing Record 453| Bridlington
# http://api.openweathermap.org/data/2.5/weather?&q=bridlington
# City not found. Skipping...
# Processing Record 454| Santa Cruz de Tenerife
# http://api.openweathermap.org/data/2.5/weather?&q=santa cruz de tenerife
# Processing Record 455| Gladstone
# http://api.openweathermap.org/data/2.5/weather?&q=gladstone
# Processing Record 456| Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?&q=ornskoldsvik
# Processing Record 457| Gavrilov-Yam
# http://api.openweathermap.org/data/2.5/weather?&q=gavrilov-yam
# Processing Record 458| Plaster Rock
# http://api.openweathermap.org/data/2.5/weather?&q=plaster rock
# Processing Record 459| Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?&q=puerto colombia
# Processing Record 460| Fenoarivo
# http://api.openweathermap.org/data/2.5/weather?&q=fenoarivo
# Processing Record 461| Saint-Denis
# http://api.openweathermap.org/data/2.5/weather?&q=saint-denis
# Processing Record 462| Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# City not found. Skipping...
# Processing Record 463| Henties Bay
# http://api.openweathermap.org/data/2.5/weather?&q=henties bay
# Processing Record 464| Ixtapa
# http://api.openweathermap.org/data/2.5/weather?&q=ixtapa
# Processing Record 465| Axim
# http://api.openweathermap.org/data/2.5/weather?&q=axim
# Processing Record 466| Novodugino
# http://api.openweathermap.org/data/2.5/weather?&q=novodugino
# Processing Record 467| Blumenau
# http://api.openweathermap.org/data/2.5/weather?&q=blumenau
# Processing Record 468| Oranjestad
# http://api.openweathermap.org/data/2.5/weather?&q=oranjestad
# Processing Record 469| Tura
# http://api.openweathermap.org/data/2.5/weather?&q=tura
# City not found. Skipping...
# Processing Record 470| Ambulu
# http://api.openweathermap.org/data/2.5/weather?&q=ambulu
# Processing Record 471| Sorland
# http://api.openweathermap.org/data/2.5/weather?&q=sorland
# Processing Record 472| Nuristan
# http://api.openweathermap.org/data/2.5/weather?&q=nuristan
# Processing Record 473| Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 474| Ariogala
# http://api.openweathermap.org/data/2.5/weather?&q=ariogala
# Processing Record 475| Westlock
# http://api.openweathermap.org/data/2.5/weather?&q=westlock
# Processing Record 476| Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?&q=srednekolymsk
# Processing Record 477| Rimini
# http://api.openweathermap.org/data/2.5/weather?&q=rimini
# Processing Record 478| Sikasso
# http://api.openweathermap.org/data/2.5/weather?&q=sikasso
# City not found. Skipping...
# Processing Record 479| Labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# Processing Record 480| Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 481| Sabha
# http://api.openweathermap.org/data/2.5/weather?&q=sabha
# Processing Record 482| Dekar
# http://api.openweathermap.org/data/2.5/weather?&q=dekar
# Processing Record 483| Crib Point
# http://api.openweathermap.org/data/2.5/weather?&q=crib point
# Processing Record 484| Avenal
# http://api.openweathermap.org/data/2.5/weather?&q=avenal
# Processing Record 485| San Bartolome
# http://api.openweathermap.org/data/2.5/weather?&q=san bartolome
# Processing Record 486| Westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 487| Shiliguri
# http://api.openweathermap.org/data/2.5/weather?&q=shiliguri
# Processing Record 488| Morbegno
# http://api.openweathermap.org/data/2.5/weather?&q=morbegno
# Processing Record 489| Kawalu
# http://api.openweathermap.org/data/2.5/weather?&q=kawalu
# Processing Record 490| Vostok
# http://api.openweathermap.org/data/2.5/weather?&q=vostok
# Processing Record 491| Neryungri
# http://api.openweathermap.org/data/2.5/weather?&q=neryungri
# Processing Record 492| Van
# http://api.openweathermap.org/data/2.5/weather?&q=van
# City not found. Skipping...
# Processing Record 493| Santiago
# http://api.openweathermap.org/data/2.5/weather?&q=santiago
# Processing Record 494| Vila Velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# City not found. Skipping...
# Processing Record 495| Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?&q=ulaanbaatar
# Processing Record 496| Bereda
# http://api.openweathermap.org/data/2.5/weather?&q=bereda
# Processing Record 497| Nizhneudinsk
# http://api.openweathermap.org/data/2.5/weather?&q=nizhneudinsk
# Processing Record 498| Oleksandrivka
# http://api.openweathermap.org/data/2.5/weather?&q=oleksandrivka
# Processing Record 499| Dingtao
# http://api.openweathermap.org/data/2.5/weather?&q=dingtao
# Processing Record 500| Coihueco
# http://api.openweathermap.org/data/2.5/weather?&q=coihueco
# Processing Record 501| Arlit
# http://api.openweathermap.org/data/2.5/weather?&q=arlit
# Processing Record 502| Coihaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 503| Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?&q=ugoofaaru
# Processing Record 504| Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 505| Somerset
# http://api.openweathermap.org/data/2.5/weather?&q=somerset
# Processing Record 506| Behat
# http://api.openweathermap.org/data/2.5/weather?&q=behat
# Processing Record 507| Berlevag
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 508| Trairi
# http://api.openweathermap.org/data/2.5/weather?&q=trairi
# Processing Record 509| Elat
# http://api.openweathermap.org/data/2.5/weather?&q=elat
# Processing Record 510| Wanlaweyn
# http://api.openweathermap.org/data/2.5/weather?&q=wanlaweyn
# Processing Record 511| Dejen
# http://api.openweathermap.org/data/2.5/weather?&q=dejen
# Processing Record 512| Dong Hoi
# http://api.openweathermap.org/data/2.5/weather?&q=dong hoi
# Processing Record 513| Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?&q=banda aceh
# Processing Record 514| Hwange
# http://api.openweathermap.org/data/2.5/weather?&q=hwange
# Processing Record 515| Pahrump
# http://api.openweathermap.org/data/2.5/weather?&q=pahrump
# Processing Record 516| Kefamenanu
# http://api.openweathermap.org/data/2.5/weather?&q=kefamenanu
# Processing Record 517| Aginskoye
# http://api.openweathermap.org/data/2.5/weather?&q=aginskoye
# Processing Record 518| Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?&q=nelson bay
# Processing Record 519| Mackay
# http://api.openweathermap.org/data/2.5/weather?&q=mackay
# Processing Record 520| Sosva
# http://api.openweathermap.org/data/2.5/weather?&q=sosva
# Processing Record 521| Angoche
# http://api.openweathermap.org/data/2.5/weather?&q=angoche
# Processing Record 522| Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 523| Loikaw
# http://api.openweathermap.org/data/2.5/weather?&q=loikaw
# Processing Record 524| Nizhnevartovsk
# http://api.openweathermap.org/data/2.5/weather?&q=nizhnevartovsk
# Processing Record 525| Khuzhir
# http://api.openweathermap.org/data/2.5/weather?&q=khuzhir
# Processing Record 526| Jaen
# http://api.openweathermap.org/data/2.5/weather?&q=jaen
# Processing Record 527| Yanam
# http://api.openweathermap.org/data/2.5/weather?&q=yanam
# Processing Record 528| Miracema do Tocantins
# http://api.openweathermap.org/data/2.5/weather?&q=miracema do tocantins
# Processing Record 529| Narasannapeta
# http://api.openweathermap.org/data/2.5/weather?&q=narasannapeta
# Processing Record 530| Toamasina
# http://api.openweathermap.org/data/2.5/weather?&q=toamasina
# City not found. Skipping...
# Processing Record 531| Okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# Processing Record 532| Pangody
# http://api.openweathermap.org/data/2.5/weather?&q=pangody
# Processing Record 533| Tual
# http://api.openweathermap.org/data/2.5/weather?&q=tual
# Processing Record 534| Carson City
# http://api.openweathermap.org/data/2.5/weather?&q=carson city
# Processing Record 535| Viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 536| Northam
# http://api.openweathermap.org/data/2.5/weather?&q=northam
# Processing Record 537| Chirongui
# http://api.openweathermap.org/data/2.5/weather?&q=chirongui
# City not found. Skipping...
# Processing Record 538| Lima
# http://api.openweathermap.org/data/2.5/weather?&q=lima
# Processing Record 539| Ayan
# http://api.openweathermap.org/data/2.5/weather?&q=ayan
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City" : city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lng" : lng,
    "Max Temp" : max_temp,
    "Wind Speed" :wind_speed,    
    }

weather_data_df = pd.DataFrame(weather_dict)
weather_data_df.count()
# Out:
# City          539
# Cloudiness    539
# Country       539
# Date          539
# Humidity      539
# Lat           539
# Lng           539
# Max Temp      539
# Wind Speed    539
# dtype: int64

# %%
weather_data_df.to_csv('weather_data.csv')
weather_data_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Rikitea           0      PF  1566429785        76 -23.12 -134.97
# 1   Yellowknife          75      CA  1566430030        49  62.45 -114.38
# 2        Atuona           0      PF  1566430030        74  -9.80 -139.03
# 3   Port Alfred           0      ZA  1566430030        82 -33.59   26.89
# 4  Punta Arenas          90      CL  1566429881        93 -53.16  -70.91
#
#    Max Temp  Wind Speed
# 0     22.22        2.26
# 1     20.56        7.70
# 2     26.82        9.02
# 3     13.33        0.45
# 4      4.00        7.70

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data_df["Lat"], weather_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (date)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("latitude_temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data_df["Lat"], weather_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (date)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("latitude_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data_df["Lat"], weather_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%))")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("latitude_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data_df["Lat"], weather_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (date)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("latitude_temperatre.png")

# Show plot
plt.show()
